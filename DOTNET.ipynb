// %%
using System;
using System.IO;

public class program
 {
 public static void Main()
     {
        var a = 5;
        Console.WriteLine("Type of a is {0}", a.GetType());
        
        var b = 5.0;
        Console.WriteLine("Type of b is {0}", b.GetType());
        
        var c = 5 > 1;
        Console.WriteLine("Type of c is {0}", c.GetType());
        
        var d = '5';
        Console.WriteLine("Type of d is {0}", d.GetType());
        
        var e = 5*2;
        Console.WriteLine("Type of e is {0}", e.GetType());
        
        var f = '5'*2;
        Console.WriteLine("Type of f is {0}", f.GetType());
        
        var g = '5' + '2';
        Console.WriteLine("Type of g is {0}", g.GetType());
        
        var h = 5/2;
        Console.WriteLine("Type of h is {0}", h.GetType());
        
        var i = 5%2;
        Console.WriteLine("Type of i is {0}", i.GetType());
        
        var j = new[] {5 , 2 ,1};
        Console.WriteLine("Type of j is {0}", j.GetType());
        
        var k = 5==3;
        Console.WriteLine("Type of k is {0}", k.GetType());
        
        var l = 3.14;
        Console.WriteLine("Type of l is {0}", l.GetType());
        
        
        
        
   
     }
 }

// %%
using System;
using System.IO;

public class program
 {
 public static void Main()
     {
      string i="Supercalifragilisticexpialidocious";
      int a= i.Length;
      Console.WriteLine(a);
      
       }
     
  }

// %%
using System;
using System.IO;

public class program
 {
 public static void Main()
     {
var b="Supercalifragilisticexpialidocious";
       var c="ice";
       if (b.Contains(c))
        {  
           Console.WriteLine("The text contains the word");
         }
      else
         {
           Console.WriteLine("The text does not contain the word");
         }
         
       }
       
   }

// %%
using System;
namespace sorting

{

  public class Program

  {

    public static void Main(string[] args)

    {

      string txt = "Supercalifragilisticexpialidocious";

      Console.WriteLine("The length of the txt string is: " + txt.Length);

      string txt2 = " Honorificabilitudinitatibus";

      Console.WriteLine("The length of the txt string is: " + txt2.Length);

      string txt3 = "Bababadalgharaghtakamminarronnkonn";

      Console.WriteLine("The length of the txt string is: " + txt3.Length);

        

      if (txt.Length > txt2.Length)

    {

        if (txt2.Length > txt3.Length)

        {

            Console.Write("Supercalifragilisticexpialidocious is bigger \n\n");

        }

        else

        {

            Console.Write("Bababadalgharaghtakamminarronnkonn is bigger \n\n");

        }

    }

    else if (txt2.Length > txt3.Length)

        Console.Write("Honorificabilitudinitatibus is bigger \n\n");

    else

        Console.Write("Bababadalgharaghtakamminarronnkonn is bigger \n\n");

    }

  }

}

// %%
using System;
namespace Heron 
{
  class HeronsFormula 
  {
    public static void main(String[] args) 
    {
      Console.WriteLine("type tbh to find the area of triangle through heron's formula");
      
      string typedvalue = Console.ReadLine();
          if (typedvalue == "tbh") 
          {
              Console.WriteLine("Type the value of first side");
                   string side1 = Console.ReadLine();
              Console.WriteLine("Type the value of second side");
                   string side2 = Console.ReadLine();
              Console.WriteLine("type the value of third side");
                   string side3 = Console.ReadLine();
              double fside = double.Parse(side1);
              double sside = double.Parse(side2);
              double thside = double.Parse(side3);
              double s = (fside + sside + thside) / 2.0;
            double har = Math.Sqrt(s * (s - fside) * (s - sside) * (s - thside));
            Console.ReadLine();
      }
    }
  }
}

// %%
using System;  
public class Exercise10 
{  
    public static void Main() 
 {
    int[] arr1 = new int[10];
    int[] arr2 = new int[10];
    int[] arr3 = new int[10];
    int i,j=0,k=0,n;


       Console.Write("\n\nSeparate odd and even integers in separate arrays:\n");
       Console.Write("------------------------------------------------------\n");

       Console.Write("Input the number of elements to be stored in the array :");
       n = Convert.ToInt32(Console.ReadLine());  
   
       Console.Write("Input {0} elements in the array :\n",n);
       for(i=0;i<n;i++)
            {
        Console.Write("element - {0} : ",i);
        arr1[i] = Convert.ToInt32(Console.ReadLine()); 
        }

    for(i=0;i<n;i++)
    {
    if (arr1[i]%2 == 0)
   {
     arr2[j] = arr1[i];
     j++;
    }
    else
    {
     arr3[k] = arr1[i];
     k++;
     }
    }

    Console.Write("\nThe Even elements are : \n");
    for(i=0;i<j;i++)
    {
    Console.Write("{0} ",arr2[i]);
    }

    Console.Write("\nThe Odd elements are :\n");
    for(i=0;i<k;i++)
    {
    Console.Write("{0} ", arr3[i]);
    }
    Console.Write("\n\n");
   }
 }

// %%
using System;
 
public class triangle
{
 
static bool FindPoint(int x1, int y1, int x2,
                      int y2, int x, int y)
{
if (x > x1 && x < x2 &&
    y > y1 && y < y2)
    return true;
 
return false;
}
 

public static void Main()
{
     
    
    int x1 = 0, y1 = 0,
        x2 = 10, y2 = 8;
 
    
    int x = 1, y = 5;
 
    
    if (FindPoint(x1, y1, x2, y2, x, y))
        Console.Write("true");
    else
        Console.Write("false");
}
}
